# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
#      |████████████████████████████████| 12.4 MB 3.3 MB/s eta 0:00:01    |██████████████                  | 5.5 MB 3.3 MB/s eta 0:00:03
# ...
#      |████████████████████████████████| 88 kB 9.0 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 67 kB 9.2 MB/s  eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#
min_rho = 0.0
max_rho = 20.0
drho=0.01
n= int((max_rho - min_rho)/drho) #cantidad de puntos o datos que se tomaran

#
rho = np.zeros(n)
R = np.zeros(n)
dR = np.zeros(n)

l=2
#Valores iniciales
if l==0:
    R[0]=1
    dR[0]=-1
else:
    R[0]=0
    dR[0]=1

print (dR)
# Out:
# [1. 0. 0. ... 0. 0. 0.]

# %%
eps=-0,99

def ddR(l,eps,rho,R,dR):
    a=-float((2*dR)/rho)
    b=float(((l(l+1))/rho**2) - 2/rho -eps)*R
    return a+b

# %%
#Solución analitica de la ecuación por el metodo de euler
for i in range(0,n-1):
    #d_R = ddR(l,eps,rho,R,dR)
    #dR += drho*d_R
    #R += dR*drho
    rho += drho
    #rho[i+1] = rho[i] + drho 
    #dR[i+1] = dR[i] + ddR(l,eps,rho[i],R[i],dR[i])*dt  
    #R[i+1] = R[i] + drho * dR[i]

print (rho)
# Out:
# [19.99 19.99 19.99 ... 19.99 19.99 19.99]

# %%
plt.plot(rho,R)
plt.show
